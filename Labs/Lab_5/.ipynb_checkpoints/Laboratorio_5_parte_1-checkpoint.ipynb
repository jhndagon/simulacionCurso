# %% [markdown]
# # Laboratorio 5 - Parte 1
#
# ### Máquinas de Vectores de Soporte
#
# ### 2018-II
#
# #### Profesor: Julián D. Arias Londoño
# #### julian.ariasl@udea.edu.co

# %% [markdown]
# ## Guía del laboratorio
#
# En esta archivo va a encontrar tanto celdas de código cómo celdas de texto con las instrucciones para desarrollar el laboratorio.
#
# Lea atentamente las instrucciones entregadas en las celdas de texto correspondientes y proceda con la solución de las preguntas planteadas.
#
# Nota: no olvide ir ejecutando las celdas de código de arriba hacia abajo para que no tenga errores de importación de librerías o por falta de definición de variables.

# %% [markdown]
# #### Primer integrante: John David Gonzalez 1017204873
# #### Segundo integrante: Mateo Llano 1045025062

# %%
from __future__ import division
import numpy as np
import math
import matplotlib.pyplot as plt
#Algunas advertencias que queremos evitar
import warnings
warnings.filterwarnings("always")
# %matplotlib inline

# %% [markdown]
# ## Ejercicio 1
#
# En este ejercicio deben resolver un problema de clasificación multi-clase usando una SVM. Teniendo en cuenta que la formulación original de la SVM sólo permite resolver problemas bi-clase, deben comparar los resultados obtenidos usando una estrategia **Uno vs Uno** con una estrategia **Uno vs El resto**.

# %% [markdown]
# Cargamos los datos:

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
digits = load_digits(n_class=4)

#--------- preprocesamiento--------------------
pca = PCA(0.99, whiten=True)
data = pca.fit_transform(digits.data)

#---------- Datos a usar ----------------------
X = data
Y = digits.target
# Out:
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/jdavid/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# Consutar el manejo de la librería sklearn para entrenar un modelos SVM en: http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC. Para el caso multiclase la librería ya tiene implementada la estrategia **Uno vs Uno**, así que en este caso sólo deben llamar correctamente los métodos. Complete el siguiente código usando un clasificador basado en SVM:

# %%
import math
import numpy as np
from numpy import random
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold

def svm(kerne, c, gamm):
    
    if(gamm == 0):
        gamm = 'auto'
    #Validamos el modelo
    Folds = 4
    random.seed(19680801)
    EficienciaTrain = np.zeros(Folds)
    EficienciaVal = np.zeros(Folds)
    porcentajeVectores = np.zeros(Folds)
    skf = StratifiedKFold(n_splits=Folds)
    j = 0
    for train, test in skf.split(X, Y):
        Xtrain = X[train,:]
        Ytrain = Y[train]
        Xtest = X[test,:]
        Ytest = Y[test]

        #Normalizamos los datos
        scaler = preprocessing.StandardScaler().fit(Xtrain)
        Xtrain = scaler.transform(Xtrain)
        Xtest = scaler.transform(Xtest)

        #Haga el llamado a la función para crear y entrenar el modelo usando los datos de entrenamiento
        modelo = SVC(C=c, kernel=kerne, decision_function_shape='ovo', gamma=gamm)
        modelo.fit(Xtrain, Ytrain)

        #Validación
        Ytrain_pred = modelo.predict(Xtrain)
        Yest = modelo.predict(Xtest)

        porcentajeVectores[j] = np.sum(modelo.n_support_)/np.shape(Xtrain)[0]

        #Evaluamos las predicciones del modelo con los datos de test
        EficienciaTrain[j] = np.mean(Ytrain_pred.ravel() == Ytrain.ravel())
        EficienciaVal[j] = np.mean(Yest.ravel() == Ytest.ravel())
        j += 1

    print('Porcentaje de vectores de soporte ', np.mean(porcentajeVectores))
    print('Eficiencia durante el entrenamiento = ' + str(np.mean(EficienciaTrain)) + '+-' + str(np.std(EficienciaTrain)))
    print('Eficiencia durante la validación = ' + str(np.mean(EficienciaVal)) + '+-' + str(np.std(EficienciaVal)))
    
    return (np.mean(EficienciaVal), np.std(EficienciaVal), np.mean(porcentajeVectores))

# %% [markdown]
# Realice los experimientos necesarios para llenar la siguiente tabla:

# %%
import pandas as pd
import qgrid
df_types = pd.DataFrame({
    'Kernel' : pd.Series(['linear','linear','linear','linear','linear','linear','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf']),
    'C' : pd.Series([0.001,0.01,0.1,1,10,100,0.001,0.001,0.001,0.01,0.01,0.01,0.1,0.1,0.1,1,1,1,10,10,10,100,100,100]),
    'gamma' : pd.Series([0,0,0,0,0,0,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1])})
df_types["Eficiencia en validacion"] = ""
df_types["Intervalo de confianza"] = ""
df_types["% de Vectores de Soporte"] = ""
df_types.set_index(['Kernel','C','gamma'], inplace=True)
df_types["Eficiencia en validacion"][3] = "0.97077"
df_types["Intervalo de confianza"][3] = "0.01548"
df_types["% de Vectores de Soporte"][3] = "0.2620"
#df_types.sort_index(inplace=True)
j=0
for i in df_types.index:
    (efival, interval, porcen) = svm(i[0], i[1], i[2])
    df_types["Eficiencia en validacion"][j] = efival
    df_types["Intervalo de confianza"][j] = interval
    df_types["% de Vectores de Soporte"][j] = porcen
    j+=1
qgrid_widget = qgrid.show_grid(df_types, show_toolbar=False)
qgrid_widget
# Out:
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.9226595902460473+-0.01797959849011947
# Eficiencia durante la validación = 0.7960012912715104+-0.053296257064013926
# Porcentaje de vectores de soporte  0.608322259431444
# Eficiencia durante el entrenamiento = 0.9967600864350297+-0.0007994779941787222
# Eficiencia durante la validación = 0.9706994383727887+-0.029264745294069673
# Porcentaje de vectores de soporte  0.28659534274928156
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9804458869759817+-0.01661113527781064
# Porcentaje de vectores de soporte  0.26203839770590365
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9707771243055832+-0.015485734683194906
# Porcentaje de vectores de soporte  0.26203839770590365
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9707771243055832+-0.015485734683194906
# Porcentaje de vectores de soporte  0.26203839770590365
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9707771243055832+-0.015485734683194906
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.3160894994308612+-0.10671453501840694
# Eficiencia durante la validación = 0.31562329600238076+-0.10806409007617507
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.28790095968964124+-0.05789068910016651
# Eficiencia durante la validación = 0.27791379879567685+-0.04275152525722977
# Porcentaje de vectores de soporte  0.9995387453874539
# Eficiencia durante el entrenamiento = 0.3174758210574786+-0.10911571093396234
# Eficiencia durante la validación = 0.2541707820359003+-0.0017169430647196973
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.3160894994308612+-0.10671453501840694
# Eficiencia durante la validación = 0.31562329600238076+-0.10806409007617507
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.28790095968964124+-0.05789068910016651
# Eficiencia durante la validación = 0.27791379879567685+-0.04275152525722977
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.3174758210574786+-0.10911571093396234
# Eficiencia durante la validación = 0.2541707820359003+-0.0017169430647196973
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.955093843689889+-0.015284560578407842
# Eficiencia durante la validación = 0.8320305656755042+-0.036448128165966764
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.28790095968964124+-0.05789068910016651
# Eficiencia durante la validación = 0.27791379879567685+-0.04275152525722977
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.3174758210574786+-0.10911571093396234
# Eficiencia durante la validación = 0.2541707820359003+-0.0017169430647196973
# Porcentaje de vectores de soporte  0.6430490683992852
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9846591128807063+-0.011521343189681546
# Porcentaje de vectores de soporte  0.9726737935808061
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.8085491566921844+-0.04070668659582277
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.25696407812528577+-0.0064859432259448254
# Porcentaje de vectores de soporte  0.5773223676135109
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9902459651590573+-0.00831727039234856
# Porcentaje de vectores de soporte  0.9722125389682599
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.8154709209984359+-0.03769775604641779
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.2583685725073082+-0.006026082774759196
# Porcentaje de vectores de soporte  0.5773223676135109
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9902459651590573+-0.00831727039234856
# Porcentaje de vectores de soporte  0.9722125389682599
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.8154709209984359+-0.03769775604641779
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.2583685725073082+-0.006026082774759196
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# Ejecute la siguiente instrucción para dejar guardados en el notebook los resultados de las pruebas.

# %%
qgrid_widget.get_changed_df()
# Out:
#                      Eficiencia en validacion Intervalo de confianza  \
# Kernel C       gamma
# linear 0.001   0.00                  0.796001              0.0532963
#        0.010   0.00                  0.970699              0.0292647
#        0.100   0.00                  0.980446              0.0166111
#        1.000   0.00                  0.970777              0.0154857
#        10.000  0.00                  0.970777              0.0154857
#        100.000 0.00                  0.970777              0.0154857
# rbf    0.001   0.01                  0.315623               0.108064
#                0.10                  0.277914              0.0427515
#                1.00                  0.254171             0.00171694
#        0.010   0.01                  0.315623               0.108064
#                0.10                  0.277914              0.0427515
#                1.00                  0.254171             0.00171694
#        0.100   0.01                  0.832031              0.0364481
#                0.10                  0.277914              0.0427515
#                1.00                  0.254171             0.00171694
#        1.000   0.01                  0.984659              0.0115213
#                0.10                  0.808549              0.0407067
#                1.00                  0.256964             0.00648594
#        10.000  0.01                  0.990246             0.00831727
#                0.10                  0.815471              0.0376978
#                1.00                  0.258369             0.00602608
#        100.000 0.01                  0.990246             0.00831727
#                0.10                  0.815471              0.0376978
#                1.00                  0.258369             0.00602608
#
#                      % de Vectores de Soporte
# Kernel C       gamma
# linear 0.001   0.00                         1
#        0.010   0.00                  0.608322
#        0.100   0.00                  0.286595
#        1.000   0.00                  0.262038
#        10.000  0.00                  0.262038
#        100.000 0.00                  0.262038
# rbf    0.001   0.01                         1
#                0.10                         1
#                1.00                  0.999539
#        0.010   0.01                         1
#                0.10                         1
#                1.00                         1
#        0.100   0.01                         1
#                0.10                         1
#                1.00                         1
#        1.000   0.01                  0.643049
#                0.10                  0.972674
#                1.00                         1
#        10.000  0.01                  0.577322
#                0.10                  0.972213
#                1.00                         1
#        100.000 0.01                  0.577322
#                0.10                  0.972213
#                1.00                         1

# %% [markdown]
# ## Ejercicio 2
#
# Cree dos funciones, una para entrenar un conjunto de modelos bajo la estrategia Uno vs el resto, usando como clasificador base una SVM. La segunda función debe usar el conjunto de modelos entrenados, y clasificar un conjunto de muestras de validación.

# %%
import pdb

def TrainSVM_OnevsRest(x, y, kerne, c, gamm):
    modelos = []
    
    for i in range(len(np.unique(y))):        
        a = np.zeros(np.shape(y)[0])        
        for j in range(len(y)):            
            if(y[j] == i):
                a[j] = 0
            else:                
                a[j] = 1                
        
        modelos.append(SVC(kernel=kerne, C=c, gamma=gamm, decision_function_shape='ovr', probability=True,).fit(x, a))        
       
    return modelos
    

def ValidaSVM_OnevsRest(modelos, x):
    #hacer la probabilidad y segun el modelo se sabe a que clase pertenece 
    #y ese vector de clases es la que se retorna
    array = np.zeros((np.shape(x)[0], len(modelos)))
    
    for i in range(len(modelos)):
        
        valores = modelos[i].predict_proba(x)
        array[:, i] = valores[:,0]
       
    return np.argmax(array,axis=1)

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Use las funciones definidas en el punto anterior para llevar a cabo la prueba de simulación con el mismo conjunto de datos del punto 1.

# %%
def svm2(kerne, c, gamm):
    if(gamm==0):
        gamm = 'auto'
    
    Folds = 4
    random.seed(19680801)
    EficienciaTrain = np.zeros(Folds)
    EficienciaVal = np.zeros(Folds)
    porcentajeVectores = np.zeros(Folds)
    skf = StratifiedKFold(n_splits=Folds)
    j = 0
    for train, test in skf.split(X, Y):
        Xtrain = X[train,:]
        Ytrain = Y[train]
        Xtest = X[test,:]
        Ytest = Y[test]

        #Normalizamos los datos
        scaler = preprocessing.StandardScaler().fit(Xtrain)
        Xtrain = scaler.transform(Xtrain)
        Xtest = scaler.transform(Xtest)

        #Haga el llamado a la función para crear y entrenar el modelo usando los datos de entrenamiento

        modelos = TrainSVM_OnevsRest(Xtrain, Ytrain, kerne, c, gamm)
        
        porcentajeVectores[j] = np.sum(modelos[j].n_support_)/np.shape(Xtrain)[0]

        #Validación
        Ytrain_pred = ValidaSVM_OnevsRest(modelos,Xtrain)
        Yest = ValidaSVM_OnevsRest(modelos,Xtest)

        #Evaluamos las predicciones del modelo con los datos de test
        EficienciaTrain[j] = np.mean(Ytrain_pred.ravel() == Ytrain.ravel())
        EficienciaVal[j] = np.mean(Yest.ravel() == Ytest.ravel())
        j += 1
    print('Porcentaje de vectores de soporte ', np.mean(porcentajeVectores))
    print('Eficiencia durante el entrenamiento = ' + str(np.mean(EficienciaTrain)) + '+-' + str(np.std(EficienciaTrain)))
    print('Eficiencia durante la validación = ' + str(np.mean(EficienciaVal)) + '+-' + str(np.std(EficienciaVal)))
    
    return (np.mean(EficienciaVal), np.std(EficienciaVal), np.mean(porcentajeVectores))

# %%
svm2('linear', 1, 0)
# Out:
# Porcentaje de vectores de soporte  0.07083308086349857
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9777370884748747+-0.01637228483712346
# (0.9777370884748747, 0.01637228483712346, 0.07083308086349857)

# %% [markdown]
# Realice los experimientos necesarios para llenar la siguiente tabla:

# %%
import pandas as pd
import qgrid
df_types = pd.DataFrame({
    'Kernel' : pd.Series(['linear','linear','linear','linear','linear','linear','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf','rbf']),
    'C' : pd.Series([0.001,0.01,0.1,1,10,100,0.001,0.001,0.001,0.01,0.01,0.01,0.1,0.1,0.1,1,1,1,10,10,10,100,100,100]),
    'gamma' : pd.Series([0,0,0,0,0,0,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1,0.01,0.1,1])})
df_types["Eficiencia en validacion"] = ""
df_types["Intervalo de confianza"] = ""
df_types["% de Vectores de Soporte"] = ""
df_types.set_index(['Kernel','C','gamma'], inplace=True)
df_types["Eficiencia en validacion"][3] = "0.97633"
df_types["Intervalo de confianza"][3] = "0.01837"
df_types["% de Vectores de Soporte"][3] = "0.2778"
#df_types.sort_index(inplace=True)
j=0
for i in df_types.index:
    (efival, interval, porcen) = svm2(i[0], i[1], i[2])
    df_types["Eficiencia en validacion"][j] = efival
    df_types["Intervalo de confianza"][j] = interval
    df_types["% de Vectores de Soporte"][j] = porcen
    j+=1
qgrid_widget = qgrid.show_grid(df_types, show_toolbar=False)
qgrid_widget
# Out:
# Porcentaje de vectores de soporte  0.5208266697432216
# Eficiencia durante el entrenamiento = 0.9921218483529499+-0.004427547973629705
# Eficiencia durante la validación = 0.9553119962869137+-0.03964865029276164
# Porcentaje de vectores de soporte  0.30042513639387014
# Eficiencia durante el entrenamiento = 0.9976860250624457+-0.0007984236624606809
# Eficiencia durante la validación = 0.9637002482333226+-0.03222408245170659
# Porcentaje de vectores de soporte  0.10276746574471561
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9749280997108298+-0.020473001729313472
# Porcentaje de vectores de soporte  0.07083308086349857
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9777370884748747+-0.01637228483712346
# Porcentaje de vectores de soporte  0.07083308086349857
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9777370884748747+-0.01637228483712346
# Porcentaje de vectores de soporte  0.07083308086349857
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9777370884748747+-0.01637228483712346
# Porcentaje de vectores de soporte  0.5009148025342705
# Eficiencia durante el entrenamiento = 0.9990732087762577+-0.0009267983881428157
# Eficiencia durante la validación = 0.9622954994681945+-0.03344191259652796
# Porcentaje de vectores de soporte  0.6337854190023653
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9016272571913161+-0.03538771504756443
# Porcentaje de vectores de soporte  0.670880192170164
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.283478924184387+-0.01758876113005494
# Porcentaje de vectores de soporte  0.5476847913589544
# Eficiencia durante el entrenamiento = 0.9990732087762577+-0.0009267983881428157
# Eficiencia durante la validación = 0.96508879555758+-0.035479270828224184
# Porcentaje de vectores de soporte  0.9731778965113296
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9196688363748069+-0.033134364483426666
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.0+-0.0
# Eficiencia durante la validación = 0.24998083790182207+-0.005660980803441695
# Porcentaje de vectores de soporte  0.5537033638763489
# Eficiencia durante el entrenamiento = 0.9995378927911276+-0.0008003931643109515
# Eficiencia durante la validación = 0.96508879555758+-0.035479270828224184
# Porcentaje de vectores de soporte  0.9801146772381477
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9196688363748069+-0.033134364483426666
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.0+-0.0
# Eficiencia durante la validación = 0.24998083790182207+-0.005660980803441695
# Porcentaje de vectores de soporte  0.3439320299963214
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9818268452042522+-0.01883439120983271
# Porcentaje de vectores de soporte  0.9689812084528904
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9349474729946228+-0.0388694801601854
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.0+-0.0
# Eficiencia durante la validación = 0.24998083790182207+-0.005660980803441695
# Porcentaje de vectores de soporte  0.28191170805111354
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9888414707770348+-0.010527068391853932
# Porcentaje de vectores de soporte  0.9666723776011807
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9446010574730475+-0.03256847869806877
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.0+-0.0
# Eficiencia durante la validación = 0.24999627047690154+-0.002953859674927187
# Porcentaje de vectores de soporte  0.28191170805111354
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9888414707770348+-0.010527068391853932
# Porcentaje de vectores de soporte  0.9666723776011807
# Eficiencia durante el entrenamiento = 1.0+-0.0
# Eficiencia durante la validación = 0.9446010574730475+-0.03256847869806877
# Porcentaje de vectores de soporte  1.0
# Eficiencia durante el entrenamiento = 0.0+-0.0
# Eficiencia durante la validación = 0.24999627047690154+-0.002953859674927187
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# Ejecute la siguiente instrucción para dejar guardados en el notebook los resultados de las pruebas.

# %%
qgrid_widget.get_changed_df()
# Out:
#                      Eficiencia en validacion Intervalo de confianza  \
# Kernel C       gamma
# linear 0.001   0.00                  0.955312              0.0396487
#        0.010   0.00                    0.9637              0.0322241
#        0.100   0.00                  0.974928               0.020473
#        1.000   0.00                  0.977737              0.0163723
#        10.000  0.00                  0.977737              0.0163723
#        100.000 0.00                  0.977737              0.0163723
# rbf    0.001   0.01                  0.962295              0.0334419
#                0.10                  0.901627              0.0353877
#                1.00                  0.283479              0.0175888
#        0.010   0.01                  0.965089              0.0354793
#                0.10                  0.919669              0.0331344
#                1.00                  0.249981             0.00566098
#        0.100   0.01                  0.965089              0.0354793
#                0.10                  0.919669              0.0331344
#                1.00                  0.249981             0.00566098
#        1.000   0.01                  0.981827              0.0188344
#                0.10                  0.934947              0.0388695
#                1.00                  0.249981             0.00566098
#        10.000  0.01                  0.988841              0.0105271
#                0.10                  0.944601              0.0325685
#                1.00                  0.249996             0.00295386
#        100.000 0.01                  0.988841              0.0105271
#                0.10                  0.944601              0.0325685
#                1.00                  0.249996             0.00295386
#
#                      % de Vectores de Soporte
# Kernel C       gamma
# linear 0.001   0.00                  0.520827
#        0.010   0.00                  0.300425
#        0.100   0.00                  0.102767
#        1.000   0.00                 0.0708331
#        10.000  0.00                 0.0708331
#        100.000 0.00                 0.0708331
# rbf    0.001   0.01                  0.500915
#                0.10                  0.633785
#                1.00                   0.67088
#        0.010   0.01                  0.547685
#                0.10                  0.973178
#                1.00                         1
#        0.100   0.01                  0.553703
#                0.10                  0.980115
#                1.00                         1
#        1.000   0.01                  0.343932
#                0.10                  0.968981
#                1.00                         1
#        10.000  0.01                  0.281912
#                0.10                  0.966672
#                1.00                         1
#        100.000 0.01                  0.281912
#                0.10                  0.966672
#                1.00                         1

# %% [markdown]
# *En las tablas el punto separa las cifras decimales, es decir 100.000 es 100 ó 1.000 es 1.
